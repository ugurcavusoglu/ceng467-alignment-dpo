# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurcavusoglu/ceng467-alignment-dpo/blob/main/notebooks/ablation_eval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir('/content')
# !git clone https://github.com/ugurcavusoglu/ceng467-alignment-dpo.git
os.chdir('/content/ceng467-alignment-dpo')
# !pip install transformers==4.44.2 trl==0.10.1 peft==0.12.0 accelerate==0.34.0 datasets bert-score evaluate -q
# Out:
# Cloning into 'ceng467-alignment-dpo'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 95 (delta 40), reused 69 (delta 23), pack-reused 0 (from 0)
# Receiving objects: 100% (95/95), 548.60 KiB | 26.12 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 158.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.1/280.1 kB 28.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 29.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.3/324.3 kB 34.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 9.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
import shutil, os

dest = '/content/ceng467-alignment-dpo/models/checkpoints'
src = '/content/drive/MyDrive/ceng467_checkpoints'

if not os.path.exists(dest):
    shutil.copytree(src, dest)
    print("Checkpoints loaded from Drive.")
else:
    print("Checkpoints already exist, skipping.")
# Out:
# Mounted at /content/drive
# Checkpoints loaded from Drive.

# %%
# !python scripts/run_eval.py \
  --base_model TinyLlama/TinyLlama-1.1B-Chat-v1.0 \
  --sft_path ./models/checkpoints/sft_50k \
  --dpo_path ./models/checkpoints/dpo_rank8 \
  --n_samples 200
# Out:
# 2026-05-30 09:06:33.887775: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-30 09:06:33.964867: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
# README.md: 5.77kB [00:00, 19.1MB/s]
# harmless-base/train.jsonl.gz: 100% 13.2M/13.2M [00:01<00:00, 8.60MB/s]
# helpful-base/train.jsonl.gz: 100% 16.2M/16.2M [00:00<00:00, 40.0MB/s]
# helpful-online/train.jsonl.gz: 100% 20.1M/20.1M [00:00<00:00, 37.7MB/s]
# helpful-rejection-sampled/train.jsonl.gz: 100% 25.7M/25.7M [00:00<00:00, 47.3MB/s]
# ...

# %%
# !python scripts/run_eval.py \
  --base_model TinyLlama/TinyLlama-1.1B-Chat-v1.0 \
  --sft_path ./models/checkpoints/sft_50k \
  --dpo_path ./models/checkpoints/dpo_rank32 \
  --n_samples 200
# Out:
# 2026-05-30 09:51:58.913738: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-30 09:51:58.989120: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
# Train samples: 159876
# Test samples:  8505
# Sample:
# {
#   "chosen": "I haven't even thought about it.",
#   "rejected": "Ass.",
# ...

# %%
# !python scripts/run_eval.py \
  --base_model TinyLlama/TinyLlama-1.1B-Chat-v1.0 \
  --sft_path ./models/checkpoints/sft_50k \
  --dpo_path ./models/checkpoints/dpo_lr5e5 \
  --n_samples 200
# Out:
# 2026-05-30 10:31:50.565413: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-30 10:31:50.636904: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
# Train samples: 159876
# Test samples:  8505
# Sample:
# {
#   "chosen": "I haven't even thought about it.",
#   "rejected": "Ass.",
# ...

# %%
# !python scripts/run_eval.py \
  --base_model TinyLlama/TinyLlama-1.1B-Chat-v1.0 \
  --sft_path ./models/checkpoints/sft_50k \
  --dpo_path ./models/checkpoints/dpo_lr1e4 \
  --n_samples 200
# Out:
# 2026-05-30 11:12:49.062422: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-30 11:12:49.133744: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
# Train samples: 159876
# Test samples:  8505
# Sample:
# {
#   "chosen": "I haven't even thought about it.",
#   "rejected": "Ass.",
# ...
